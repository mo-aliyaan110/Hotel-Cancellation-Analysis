# %% [markdown]
# # Importing Libraries

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# # Loading the dataset

# %%
df = pd.read_csv('./DataSets/hotel_bookings 2.csv')

# %% [markdown]
# # Exploratory Data Analysis and Data Cleaning

# %%
df.head()
# Out:
#           hotel  is_canceled  lead_time  arrival_date_year arrival_date_month  \
# 0  Resort Hotel            0        342               2015               July
# 1  Resort Hotel            0        737               2015               July
# 2  Resort Hotel            0          7               2015               July
# 3  Resort Hotel            0         13               2015               July
# 4  Resort Hotel            0         14               2015               July
#
#    arrival_date_week_number  arrival_date_day_of_month  \
# 0                        27                          1
# 1                        27                          1
# 2                        27                          1
# 3                        27                          1
# 4                        27                          1
#
#    stays_in_weekend_nights  stays_in_week_nights  adults  ...  deposit_type  \
# 0                        0                     0       2  ...    No Deposit
# ...

# %%
df.tail()
# Out:
#              hotel  is_canceled  lead_time  arrival_date_year  \
# 119385  City Hotel            0         23               2017
# 119386  City Hotel            0        102               2017
# 119387  City Hotel            0         34               2017
# 119388  City Hotel            0        109               2017
# 119389  City Hotel            0        205               2017
#
#        arrival_date_month  arrival_date_week_number  \
# 119385             August                        35
# 119386             August                        35
# 119387             August                        35
# 119388             August                        35
# 119389             August                        35
#
#         arrival_date_day_of_month  stays_in_weekend_nights  \
# 119385                         30                        2
# 119386                         31                        2
# 119387                         31                        2
# ...

# %%
df.shape
# Out:
# (119390, 32)

# %%
df.columns
# Out:
# Index(['hotel', 'is_canceled', 'lead_time', 'arrival_date_year',
#        'arrival_date_month', 'arrival_date_week_number',
#        'arrival_date_day_of_month', 'stays_in_weekend_nights',
#        'stays_in_week_nights', 'adults', 'children', 'babies', 'meal',
#        'country', 'market_segment', 'distribution_channel',
#        'is_repeated_guest', 'previous_cancellations',
#        'previous_bookings_not_canceled', 'reserved_room_type',
#        'assigned_room_type', 'booking_changes', 'deposit_type', 'agent',
#        'company', 'days_in_waiting_list', 'customer_type', 'adr',
#        'required_car_parking_spaces', 'total_of_special_requests',
#        'reservation_status', 'reservation_status_date'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 119390 entries, 0 to 119389
# Data columns (total 32 columns):
#  #   Column                          Non-Null Count   Dtype
# ---  ------                          --------------   -----
#  0   hotel                           119390 non-null  object
#  1   is_canceled                     119390 non-null  int64
#  2   lead_time                       119390 non-null  int64
#  3   arrival_date_year               119390 non-null  int64
#  4   arrival_date_month              119390 non-null  object
#  5   arrival_date_week_number        119390 non-null  int64
#  6   arrival_date_day_of_month       119390 non-null  int64
#  7   stays_in_weekend_nights         119390 non-null  int64
#  8   stays_in_week_nights            119390 non-null  int64
#  9   adults                          119390 non-null  int64
#  10  children                        119386 non-null  float64
#  11  babies                          119390 non-null  int64
# ...

# %% [raw]
# # Now here the reservation_status_date is in object datatype, we have to do the analysis on this variable. So, we will convert this variable to a datetime format

# %%
df['reservation_status_date'] = pd.to_datetime(df['reservation_status_date'])

# %% [raw]
# # Now let's see number of subclasses present in categorical variables

# %%
df.describe(include='object')
# Out:
#              hotel arrival_date_month    meal country market_segment  \
# count       119390             119390  119390  118902         119390
# unique           2                 12       5     177              8
# top     City Hotel             August      BB     PRT      Online TA
# freq         79330              13877   92310   48590          56477
#
#        distribution_channel reserved_room_type assigned_room_type  \
# count                119390             119390             119390
# unique                    5                 10                 12
# top                   TA/TO                  A                  A
# freq                  97870              85994              74053
#
#        deposit_type customer_type reservation_status
# count        119390        119390             119390
# unique            3             4                  3
# top      No Deposit     Transient          Check-Out
# freq         104641         89613              75166

# %% [raw]
# # Now you have seen the number of unique subclasses in the variables, now let's see what are the names of these categories

# %%
for cols in df.describe(include='object').columns:
    print(cols)
    print(df[cols].unique())
    print('-'*50)
# Out:
# hotel
# ['Resort Hotel' 'City Hotel']
# --------------------------------------------------
# arrival_date_month
# ['July' 'August' 'September' 'October' 'November' 'December' 'January'
#  'February' 'March' 'April' 'May' 'June']
# --------------------------------------------------
# meal
# ['BB' 'FB' 'HB' 'SC' 'Undefined']
# --------------------------------------------------
# country
# ['PRT' 'GBR' 'USA' 'ESP' 'IRL' 'FRA' nan 'ROU' 'NOR' 'OMN' 'ARG' 'POL'
#  'DEU' 'BEL' 'CHE' 'CN' 'GRC' 'ITA' 'NLD' 'DNK' 'RUS' 'SWE' 'AUS' 'EST'
#  'CZE' 'BRA' 'FIN' 'MOZ' 'BWA' 'LUX' 'SVN' 'ALB' 'IND' 'CHN' 'MEX' 'MAR'
#  'UKR' 'SMR' 'LVA' 'PRI' 'SRB' 'CHL' 'AUT' 'BLR' 'LTU' 'TUR' 'ZAF' 'AGO'
#  'ISR' 'CYM' 'ZMB' 'CPV' 'ZWE' 'DZA' 'KOR' 'CRI' 'HUN' 'ARE' 'TUN' 'JAM'
#  'HRV' 'HKG' 'IRN' 'GEO' 'AND' 'GIB' 'URY' 'JEY' 'CAF' 'CYP' 'COL' 'GGY'
#  'KWT' 'NGA' 'MDV' 'VEN' 'SVK' 'FJI' 'KAZ' 'PAK' 'IDN' 'LBN' 'PHL' 'SEN'
#  'SYC' 'AZE' 'BHR' 'NZL' 'THA' 'DOM' 'MKD' 'MYS' 'ARM' 'JPN' 'LKA' 'CUB'
# ...

# %%
df.isnull().sum()
# Out:
# hotel                                  0
# is_canceled                            0
# lead_time                              0
# arrival_date_year                      0
# arrival_date_month                     0
# arrival_date_week_number               0
# arrival_date_day_of_month              0
# stays_in_weekend_nights                0
# stays_in_week_nights                   0
# adults                                 0
# children                               4
# babies                                 0
# meal                                   0
# country                              488
# market_segment                         0
# distribution_channel                   0
# is_repeated_guest                      0
# previous_cancellations                 0
# previous_bookings_not_canceled         0
# reserved_room_type                     0
# assigned_room_type                     0
# booking_changes                        0
# deposit_type                           0
# ...

# %% [raw]
# # We do not want the variables agent, as it has a lot of missing values and company also has a lot of missing values. So we shall remove these two variables.

# %%
df.drop(['agent', 'company'], axis=1, inplace=True)

# %%
df.dropna(inplace=True)

# %%
df.isnull().sum()
# Out:
# hotel                             0
# is_canceled                       0
# lead_time                         0
# arrival_date_year                 0
# arrival_date_month                0
# arrival_date_week_number          0
# arrival_date_day_of_month         0
# stays_in_weekend_nights           0
# stays_in_week_nights              0
# adults                            0
# children                          0
# babies                            0
# meal                              0
# country                           0
# market_segment                    0
# distribution_channel              0
# is_repeated_guest                 0
# previous_cancellations            0
# previous_bookings_not_canceled    0
# reserved_room_type                0
# assigned_room_type                0
# booking_changes                   0
# deposit_type                      0
# days_in_waiting_list              0
# customer_type                     0
# adr                               0
# ...

# %%
df.describe()
# Out:
#          is_canceled      lead_time  arrival_date_year  \
# count  118898.000000  118898.000000      118898.000000
# mean        0.371352     104.311435        2016.157656
# std         0.483168     106.903309           0.707459
# min         0.000000       0.000000        2015.000000
# 25%         0.000000      18.000000        2016.000000
# 50%         0.000000      69.000000        2016.000000
# 75%         1.000000     161.000000        2017.000000
# max         1.000000     737.000000        2017.000000
#
#        arrival_date_week_number  arrival_date_day_of_month  \
# count             118898.000000              118898.000000
# mean                  27.166555                  15.800880
# std                   13.589971                   8.780324
# min                    1.000000                   1.000000
# 25%                   16.000000                   8.000000
# 50%                   28.000000                  16.000000
# ...

# %% [raw]
# # In the adr, we have found the outliers, which we have to remove, the adr minimum is -6 and maximum is 5400 which is very high value, so lets remove it.

# %% [raw]
# # see the box plot of adr

# %%
df['adr'].plot(kind='box')
# Out:
# <AxesSubplot:>

# %% [raw]
# # You can see only one datapoint is above 5000 and the majority of datapoints are below 1000. So lets remove it

# %%
df = df[df['adr']<5000]

# %%
df.describe()
# Out:
#          is_canceled      lead_time  arrival_date_year  \
# count  118897.000000  118897.000000      118897.000000
# mean        0.371347     104.312018        2016.157657
# std         0.483167     106.903570           0.707462
# min         0.000000       0.000000        2015.000000
# 25%         0.000000      18.000000        2016.000000
# 50%         0.000000      69.000000        2016.000000
# 75%         1.000000     161.000000        2017.000000
# max         1.000000     737.000000        2017.000000
#
#        arrival_date_week_number  arrival_date_day_of_month  \
# count             118897.000000              118897.000000
# mean                  27.166674                  15.800802
# std                   13.589966                   8.780321
# min                    1.000000                   1.000000
# 25%                   16.000000                   8.000000
# 50%                   28.000000                  16.000000
# ...

# %% [markdown]
# # Data Analysis and Visualizations

# %%
cancelled_perc = df['is_canceled'].value_counts(normalize=True)
print(cancelled_perc)

plt.figure(figsize=(5,4))
plt.title('Count of cancellation status')
plt.bar(['Not Cancelled', 'Cancelled'], df['is_canceled'].value_counts(), edgecolor='k', width=0.7)
plt.show()
# Out:
# 0    0.628653
# 1    0.371347
# Name: is_canceled, dtype: float64

# %% [raw]
# # Now lets see cancellation count on the basis of hotels

# %%
df.head(2)
# Out:
#           hotel  is_canceled  lead_time  arrival_date_year arrival_date_month  \
# 0  Resort Hotel            0        342               2015               July
# 1  Resort Hotel            0        737               2015               July
#
#    arrival_date_week_number  arrival_date_day_of_month  \
# 0                        27                          1
# 1                        27                          1
#
#    stays_in_weekend_nights  stays_in_week_nights  adults  ...  \
# 0                        0                     0       2  ...
# 1                        0                     0       2  ...
#
#    assigned_room_type  booking_changes deposit_type days_in_waiting_list  \
# 0                   C                3   No Deposit                    0
# 1                   C                4   No Deposit                    0
#
#   customer_type  adr  required_car_parking_spaces  total_of_special_requests  \
# ...

# %%
plt.figure(figsize=(8,4))
ax1=sns.countplot(x='hotel', hue='is_canceled', data=df, palette='Greens')
# legend_labels = ax1.get_legend_handles_labels()
# ax1.legend(bbox_to_anchor(1,1))
plt.title('Reservation status in different hotels', size=20)
plt.xlabel('hotel')
plt.ylabel('number of reservations')
plt.legend(fontsize=15)
plt.show()

# %%
# Now let's see the cancellation percentage of both hotels types

# %%
df.head(2)
# Out:
#           hotel  is_canceled  lead_time  arrival_date_year arrival_date_month  \
# 0  Resort Hotel            0        342               2015               July
# 1  Resort Hotel            0        737               2015               July
#
#    arrival_date_week_number  arrival_date_day_of_month  \
# 0                        27                          1
# 1                        27                          1
#
#    stays_in_weekend_nights  stays_in_week_nights  adults  ...  \
# 0                        0                     0       2  ...
# 1                        0                     0       2  ...
#
#    assigned_room_type  booking_changes deposit_type days_in_waiting_list  \
# 0                   C                3   No Deposit                    0
# 1                   C                4   No Deposit                    0
#
#   customer_type  adr  required_car_parking_spaces  total_of_special_requests  \
# ...

# %%
resort_hotel = df[df['hotel']=='Resort Hotel']
resort_hotel['is_canceled'].value_counts(normalize=True)
# Out:
# 0    0.72025
# 1    0.27975
# Name: is_canceled, dtype: float64

# %%
city_hotel = df[df['hotel']=='City Hotel']
city_hotel['is_canceled'].value_counts(normalize=True)
# Out:
# 0    0.582918
# 1    0.417082
# Name: is_canceled, dtype: float64

# %%
df.head(3)
# Out:
#           hotel  is_canceled  lead_time  arrival_date_year arrival_date_month  \
# 0  Resort Hotel            0        342               2015               July
# 1  Resort Hotel            0        737               2015               July
# 2  Resort Hotel            0          7               2015               July
#
#    arrival_date_week_number  arrival_date_day_of_month  \
# 0                        27                          1
# 1                        27                          1
# 2                        27                          1
#
#    stays_in_weekend_nights  stays_in_week_nights  adults  ...  \
# 0                        0                     0       2  ...
# 1                        0                     0       2  ...
# 2                        0                     1       1  ...
#
#    assigned_room_type  booking_changes deposit_type days_in_waiting_list  \
# 0                   C                3   No Deposit                    0
# ...

# %% [raw]
# # now we have to check the adr (average daily rate of each type of hotel for each day), for that we will use groupby function and pass the reservation_status_date, and take the mean of adr. for both the hotels.

# %%
resort_hotel = resort_hotel.groupby('reservation_status_date')[['adr']].mean()
city_hotel = city_hotel.groupby('reservation_status_date')[['adr']].mean()

# %%
# Now its time to plot the results.

# %%
plt.figure(figsize=(20,8))
plt.title('Average Daily Rate in City and Resort Hotel', size='20')
plt.plot(resort_hotel.index, resort_hotel['adr'], label='Resort Hotel')
plt.plot(city_hotel.index, city_hotel['adr'], label='City Hotel')
plt.legend(fontsize=20)
plt.show()

# %%
# Now we need to check on what month, there were more reservations and which month had the more cancellations.

# %%
df.head(3)
# Out:
#           hotel  is_canceled  lead_time  arrival_date_year arrival_date_month  \
# 0  Resort Hotel            0        342               2015               July
# 1  Resort Hotel            0        737               2015               July
# 2  Resort Hotel            0          7               2015               July
#
#    arrival_date_week_number  arrival_date_day_of_month  \
# 0                        27                          1
# 1                        27                          1
# 2                        27                          1
#
#    stays_in_weekend_nights  stays_in_week_nights  adults  ...  \
# 0                        0                     0       2  ...
# 1                        0                     0       2  ...
# 2                        0                     1       1  ...
#
#    assigned_room_type  booking_changes deposit_type days_in_waiting_list  \
# 0                   C                3   No Deposit                    0
# ...

# %%
df['month'] = df['reservation_status_date'].dt.month

plt.figure(figsize=(16, 8))
plt.title('Reservation Status Per Month.', size=20)
sns.countplot(x='month', hue='is_canceled', data=df,  palette='bright' )
plt.xlabel('months')
plt.ylabel('number of reservations')
plt.legend(['not_cancelled', 'cancelled'],fontsize=10)
plt.show()

# %% [raw]
# # When there are more reservations, there are less cancellations, also, when there are more cancellations, there are less reservations

# %%
# plt.figure(figsize=(10, 10))

# sns.countplot('month', hue='adr', data=df, palette='Blues')
# plt.title('Months as per Average Daily Rate')
# plt.xlabel('months')
# plt.ylabel('Adr values')
# plt.show()

# %%
df.head(2)
# Out:
#           hotel  is_canceled  lead_time  arrival_date_year arrival_date_month  \
# 0  Resort Hotel            0        342               2015               July
# 1  Resort Hotel            0        737               2015               July
#
#    arrival_date_week_number  arrival_date_day_of_month  \
# 0                        27                          1
# 1                        27                          1
#
#    stays_in_weekend_nights  stays_in_week_nights  adults  ...  \
# 0                        0                     0       2  ...
# 1                        0                     0       2  ...
#
#    booking_changes  deposit_type days_in_waiting_list customer_type  adr  \
# 0                3    No Deposit                    0     Transient  0.0
# 1                4    No Deposit                    0     Transient  0.0
#
#   required_car_parking_spaces  total_of_special_requests  reservation_status  \
# ...

# %%
# Now we shall see that if our cancellation rate have any effect on the adr, we shall use now bar plot as we have only one class in the hue

# %%
plt.figure(figsize=(15,8))

plt.title("Average daily rate of each month", size=20)

sns.barplot('month', 'adr', data=df[df['is_canceled']==1].groupby('month')[['adr']].sum().reset_index())
plt.xlabel('Months')
plt.ylabel('Average Daily Rate')
plt.show()

# %% [raw]
# # Now our hypothesis has proved, we failed to reject the null hypothesis, claiming that whenever there is low price in hotels, then there are less cancellations.

# %%
# Now we shall see, which country has higher cancellation rates.

# %%
cancelled = df[df['is_canceled']==1]

top_10_countries = cancelled['country'].value_counts()[:10]
plt.figure(figsize=(10,8))

plt.title('Cancellation rates in Top 10 Countries', size=20)
plt.pie(top_10_countries, autopct='%.2f', labels= top_10_countries.index)
plt.show()

# %%
# Now lets see from what channels were more reservations happening?

# %%
df.head(10)
# Out:
#           hotel  is_canceled  lead_time  arrival_date_year arrival_date_month  \
# 0  Resort Hotel            0        342               2015               July
# 1  Resort Hotel            0        737               2015               July
# 2  Resort Hotel            0          7               2015               July
# 3  Resort Hotel            0         13               2015               July
# 4  Resort Hotel            0         14               2015               July
# 5  Resort Hotel            0         14               2015               July
# 6  Resort Hotel            0          0               2015               July
# 7  Resort Hotel            0          9               2015               July
# 8  Resort Hotel            1         85               2015               July
# 9  Resort Hotel            1         75               2015               July
#
#    arrival_date_week_number  arrival_date_day_of_month  \
# ...

# %%
df['market_segment'].value_counts()
# Out:
# Online TA        56402
# Offline TA/TO    24159
# Groups           19806
# Direct           12448
# Corporate         5111
# Complementary      734
# Aviation           237
# Name: market_segment, dtype: int64

# %%
df['market_segment'].value_counts(normalize=True)
# Out:
# Online TA        0.474377
# Offline TA/TO    0.203193
# Groups           0.166581
# Direct           0.104696
# Corporate        0.042987
# Complementary    0.006173
# Aviation         0.001993
# Name: market_segment, dtype: float64

# %%
# This fails our assumption that most of the reservations are from offline TA.

# %%
# Lets see this percentage in the cancelled data.

# %%
cancelled['market_segment'].value_counts(normalize=True)
# Out:
# Online TA        0.469696
# Groups           0.273985
# Offline TA/TO    0.187466
# Direct           0.043486
# Corporate        0.022151
# Complementary    0.002038
# Aviation         0.001178
# Name: market_segment, dtype: float64

# %%
# Now we shall see the price/adr is high for cancelled hotels or adr is high for not cancelled hotels??

# %%
not_cancelled = df[df['is_canceled']==0]

# %%
not_cnc_adr = not_cancelled.groupby('reservation_status_date')[['adr']].mean()
not_cnc_adr.reset_index(inplace=True)
not_cnc_adr.sort_values('reservation_status_date', inplace=True)


cancelled_adr = cancelled.groupby('reservation_status_date')[['adr']].mean()
cancelled_adr.reset_index(inplace=True)
cancelled_adr.sort_values('reservation_status_date', inplace=True)

plt.figure(figsize=(20, 6))
plt.title("ADR based on Cancelled and Not Cancelled Hotels", size=30)
plt.plot(not_cnc_adr['reservation_status_date'], not_cnc_adr['adr'], label='not_cancel')
plt.plot(cancelled_adr['reservation_status_date'], cancelled_adr['adr'], label='cancel')
plt.legend(fontsize=20)

plt.show()

# %%
twenty_sixten = cancelled_adr['reservation_status_date']>='2016-01'
lessthan_2017 = cancelled_adr['reservation_status_date']<'2017-09'
cancelled_adr = cancelled_adr[twenty_sixten & lessthan_2017]

not_cancelled_adr = not_cnc_adr[(not_cnc_adr['reservation_status_date']>='2016') & (not_cnc_adr['reservation_status_date']<'2017-09')]

# %% [raw]
# # There is inconsistent data present during the year 2015 and after 2017-09, so we shall filter the data from 2016 to 2017-09

# %%
plt.figure(figsize=(20,6))

plt.title("ADR based on Hotel cancellation", fontsize=20)
plt.plot(not_cancelled_adr['reservation_status_date'], not_cancelled_adr['adr'], label='not_cancelled')
plt.plot(cancelled_adr['reservation_status_date'], cancelled_adr['adr'], label='cancelled')
plt.legend(fontsize=20)
plt.show()

# %% [raw]
# # Here we are now confirmed that that as the average daily rate is increasing, so the cancellation rates are increasing.
